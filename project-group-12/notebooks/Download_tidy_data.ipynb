# %% [markdown]
# # Question 1

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd

# %%
from ift6758.data.data_Acquisition import dataDownload

# %%
from ift6758.data.tidy_data import tidyData

# %% [markdown]
# If the above doesn't work for you, make sure you've installed the repo as specified in the readme file.
# Essentially you must make sure that your environment is setup (either through conda or virtualenv), and then install it using:
#
# ```bash
# pip install -e /path/to/repo
# ```
#
# The nice thing using this approach is if you have your environment activated, you can import modules from anywhere on your system!

# %%
years = (2016, 2017,2018,2019,2020,2021)
for i in years : 
    dataDownload(i)
# Out:
# file already exsiste
# file already exsiste
# file already exsiste
# file already exsiste
# file already exsiste
# file already exsiste

# %%
years = (2016, 2017,2018,2019,2020,2021)
for i in years : 
    tidyData(i)
# Out:
# file already exsiste
# file already exsiste
# file already exsiste
# file already exsiste
# file already exsiste
# file already exsiste

# %%
df_2021 = pd.read_csv('./2021finalDataset.csv')

# %%
df_2021.head(10)
# Out:
#        gameID eventType  period periodTime periodType        teamOfShooter  \
# 0  2021020001      Shot       1      01:03    REGULAR  Tampa Bay Lightning
# 1  2021020001      Shot       1      01:44    REGULAR  Pittsburgh Penguins
# 2  2021020001      Shot       1      02:01    REGULAR  Tampa Bay Lightning
# 3  2021020001      Shot       1      02:47    REGULAR  Pittsburgh Penguins
# 4  2021020001      Shot       1      03:07    REGULAR  Tampa Bay Lightning
# 5  2021020001      Shot       1      04:32    REGULAR  Pittsburgh Penguins
# 6  2021020001      Shot       1      04:39    REGULAR  Pittsburgh Penguins
# 7  2021020001      Shot       1      05:11    REGULAR  Tampa Bay Lightning
# 8  2021020001      Shot       1      05:18    REGULAR  Pittsburgh Penguins
# 9  2021020001      Shot       1      05:45    REGULAR  Pittsburgh Penguins
#
#   homeOrAway  xCoord  yCoord         shooter              goalie    shotType  \
# 0       home    61.0   -32.0  Steven Stamkos       Tristan Jarry  Wrist Shot
# 1       away   -65.0    19.0    Brock McGinn  Andrei Vasilevskiy  Wrist Shot
# 2       home    -8.0   -27.0       Jan Rutta       Tristan Jarry  Wrist Shot
# 3       away   -60.0    -4.0   Danton Heinen  Andrei Vasilevskiy  Wrist Shot
# 4       home    63.0     4.0    Ondrej Palat       Tristan Jarry  Wrist Shot
# 5       away   -63.0   -33.0   Mark Friedman  Andrei Vasilevskiy  Wrist Shot
# 6       away   -61.0   -10.0   Dominik Simon  Andrei Vasilevskiy   Slap Shot
# 7       home    64.0    31.0   Victor Hedman       Tristan Jarry  Wrist Shot
# 8       away   -75.0    -9.0      Bryan Rust  Andrei Vasilevskiy    Backhand
# 9       away   -73.0    12.0   Drew O'Connor  Andrei Vasilevskiy  Wrist Shot
#
#   emptyNet strength  season rinkSide
# 0      NaN      NaN    2021     left
# 1      NaN      NaN    2021    right
# 2      NaN      NaN    2021     left
# 3      NaN      NaN    2021    right
# 4      NaN      NaN    2021     left
# 5      NaN      NaN    2021    right
# 6      NaN      NaN    2021    right
# 7      NaN      NaN    2021     left
# 8      NaN      NaN    2021    right
# 9      NaN      NaN    2021    right
